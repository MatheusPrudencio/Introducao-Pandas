# %%
import pandas as pd

# %matplotlib inline

# %%
df = pd.read_csv('cursos-prouni.csv')

# Formato (Linhas, colunas)
df.shape
# Out:
# (41447, 16)

# %%
df.dtypes
# Out:
# uf_busca                 object
# cidade_busca             object
# universidade_nome        object
# campus_nome              object
# nome                     object
# grau                     object
# turno                    object
# mensalidade             float64
# bolsa_integral_cotas    float64
# bolsa_integral_ampla    float64
# bolsa_parcial_cotas     float64
# bolsa_parcial_ampla     float64
# nota_integral_ampla     float64
# nota_integral_cotas     float64
# nota_parcial_ampla      float64
# nota_parcial_cotas      float64
# dtype: object

# %%
# Análise matematica das colunas
df.describe()

#STD = desvio padrão
# Out:
#         mensalidade  bolsa_integral_cotas  bolsa_integral_ampla  \
# count  41447.000000          32520.000000          25404.000000
# mean     622.636966              1.535394              2.513541
# std      606.442296              2.191578              3.019549
# min      139.000000              0.000000              1.000000
# 25%      278.000000              0.000000              1.000000
# 50%      393.350000              1.000000              1.000000
# 75%      825.000000              2.000000              3.000000
# max     9999.990000             58.000000             67.000000
#
#        bolsa_parcial_cotas  bolsa_parcial_ampla  nota_integral_ampla  \
# count          8828.000000         13041.000000         32520.000000
# mean              1.873018             8.632544           575.982999
# std               2.336403            18.372991            57.827594
# min               1.000000             1.000000           450.000000
# ...

# %%
# Descrever os dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41447 entries, 0 to 41446
# Data columns (total 16 columns):
# uf_busca                41447 non-null object
# cidade_busca            41447 non-null object
# universidade_nome       41447 non-null object
# campus_nome             41447 non-null object
# nome                    41447 non-null object
# grau                    41447 non-null object
# turno                   41447 non-null object
# mensalidade             41447 non-null float64
# bolsa_integral_cotas    32520 non-null float64
# bolsa_integral_ampla    25404 non-null float64
# bolsa_parcial_cotas     8828 non-null float64
# bolsa_parcial_ampla     13041 non-null float64
# nota_integral_ampla     32520 non-null float64
# nota_integral_cotas     16802 non-null float64
# nota_parcial_ampla      16350 non-null float64
# nota_parcial_cotas      5519 non-null float64
# dtypes: float64(9), object(7)
# memory usage: 5.1+ MB

# %%
df['uf_busca'].value_counts()
# Out:
# SP    11533
# MG     4175
# PR     3918
# RS     3060
# BA     2505
# SC     2195
# RJ     1442
# GO     1278
# PA     1201
# PE     1148
# DF     1063
# MT     1063
# ES      825
# CE      816
# MS      785
# MA      679
# PB      596
# RO      463
# AM      429
# PI      405
# TO      343
# RN      342
# AL      327
# SE      323
# AP      219
# AC      203
# RR      111
# Name: uf_busca, dtype: int64

# %%
# Qual o curso com a mensalidade mais alta?

df[df['mensalidade'] == df['mensalidade'].max()]
# Out:
#       uf_busca  cidade_busca                  universidade_nome  \
# 31987       MS  Campo Grande  Universidade Anhanguera - UNIDERP
#
#                               campus_nome      nome         grau     turno  \
# 31987  CAMPO GRANDE - SEDE - Miguel Couto  Medicina  Bacharelado  Integral
#
#        mensalidade  bolsa_integral_cotas  bolsa_integral_ampla  \
# 31987      9999.99                  15.0                  14.0
#
#        bolsa_parcial_cotas  bolsa_parcial_ampla  nota_integral_ampla  \
# 31987                  NaN                  NaN               740.22
#
#        nota_integral_cotas  nota_parcial_ampla  nota_parcial_cotas
# 31987               726.46                 NaN                 NaN

# %%
# DESAFIO
# Analisar o curso de medicina com mais de 5000 de mensalidade

df_1= df[df['mensalidade'] >= 5000]

# %%
df_1.count()
# Out:
# uf_busca                145
# cidade_busca            145
# universidade_nome       145
# campus_nome             145
# nome                    145
# grau                    145
# turno                   145
# mensalidade             145
# bolsa_integral_cotas    140
# bolsa_integral_ampla    134
# bolsa_parcial_cotas      25
# bolsa_parcial_ampla      28
# nota_integral_ampla     140
# nota_integral_cotas     118
# nota_parcial_ampla       30
# nota_parcial_cotas       23
# dtype: int64

# %%
df_1.sample(6)
# Out:
#       uf_busca cidade_busca  \
# 32015       RJ      Valenca
# 16790       PR     Curitiba
# 10577       PR     Curitiba
# 31981       MG   Ponte Nova
# 32051       SP    Rio Claro
# 32061       TO    Araguaina
#
#                                        universidade_nome  \
# 32015  Centro de Ensino Superior de Valença - Cesva -...
# 16790  Faculdade Anchieta de Ensino Superior do Paran...
# 10577                          Faculdade Dom Bosco - FDB
# 31981      Faculdade Dinâmica do Vale do Piranga - FADIP
# 32051  Claretiano - Faculdade - Claretianorc - CLARET...
# 32061  Centro Universitário Tocantinense Presidente A...
#
#                                   campus_nome                   nome  \
# 32015  UNIDADE DOM JOSÉ COSTA CAMPOS - Centro               Medicina
# 16790        UNIDADE SEDE - Cidade Industrial  Engenharia Eletrônica
# 10577                       MARUMBY - Lindóia                Direito
# 31981                  UNIDADE SEDE - Paraíso               Medicina
# ...

# %%
df_1.tail(6)
# Out:
#       uf_busca    cidade_busca  \
# 32060       SP        Sorocaba
# 32061       TO       Araguaina
# 32062       TO          Palmas
# 32063       TO  Porto Nacional
# 37058       CE         Crateus
# 37310       PR        Curitiba
#
#                                        universidade_nome  \
# 32060  Pontifícia Universidade Católica de São Paulo ...
# 32061  Centro Universitário Tocantinense Presidente A...
# 32062  Faculdade de Ciências Humanas, Econômicas e da...
# 32063        Faculdade Presidente Antônio Carlos - FAPAC
# 37058                  Faculdade Princesa do Oeste - FPO
# 37310                          Faculdade Dom Bosco - FDB
#
#                                              campus_nome        nome  \
# 32060                SOROCABA - CAMPUS SOROCABA - Centro    Medicina
# 32061                     CAMPUS ARAGUAÍNA - Setor Oeste    Medicina
# 32062  FACULDADE DE CIÊNCIAS HUMANAS, ECONÔMICAS E DA...    Medicina
# ...

# %%
df_1['nome'].value_counts()
# Out:
# Medicina                            122
# Enfermagem                            3
# Direito                               2
# Psicologia                            2
# Administração                         2
# Fisioterapia                          2
# Engenharia de Produção                2
# Engenharia Civil                      2
# Educação Física                       2
# Ciências Contábeis                    1
# Engenharia Ambiental e Sanitária      1
# Arquitetura e Urbanismo               1
# Engenharia Mecânica                   1
# Engenharia Eletrônica                 1
# Engenharia de Computação              1
# Name: nome, dtype: int64

# %%
df_med = df_1[df_1['nome'].str.contains('Med')]

# %%
df_med.describe()
# Out:
#        mensalidade  bolsa_integral_cotas  bolsa_integral_ampla  \
# count   122.000000            120.000000            115.000000
# mean   7206.500820              3.925000              4.565217
# std    1051.852516              3.338501              3.618012
# min    5220.850000              0.000000              1.000000
# 25%    6403.040000              1.000000              2.000000
# 50%    7230.355000              3.000000              4.000000
# 75%    7824.525000              5.000000              5.000000
# max    9999.990000             15.000000             19.000000
#
#        bolsa_parcial_cotas  bolsa_parcial_ampla  nota_integral_ampla  \
# count            23.000000            22.000000           120.000000
# mean              3.739130             3.727273           749.778500
# std               2.378261             2.566855            10.424104
# min               1.000000             1.000000           732.700000
# ...

# %%
# Desafio
# Cursos que eu conseguiria entrar nas cidades de SP, Santo André, São Bernardo e São Caetano com 670 de nota

df_eu = df[df['cidade_busca']=='Sao Paulo'or df['cidade_busca']=='Santo Andre'  ]
# Colocando colchetes depois escolho apenas essas colunas p/ o novo df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-702c5761a044> in <module>
#       2 # Cursos que eu conseguiria entrar nas cidades de SP, Santo André, São Bernardo e São Caetano com 670 de nota
#       3
# ----> 4 df_eu = df[df['cidade_busca']=='Sao Paulo'or df['cidade_busca']=='Santo Andre'  ]
#       5 # Colocando colchetes depois escolho apenas essas colunas p/ o novo df
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ...

# %%
df_eu.sample(506)
# Out:
#       uf_busca cidade_busca  \
# 18563       SP    Sao Paulo
# 16800       SP    Sao Paulo
# 26851       SP    Sao Paulo
# 24761       SP    Sao Paulo
# 5569        SP    Sao Paulo
# 37587       SP    Sao Paulo
# 13877       SP    Sao Paulo
# 36959       SP    Sao Paulo
# 22134       SP    Sao Paulo
# 4012        SP    Sao Paulo
# 8404        SP    Sao Paulo
# 24235       SP    Sao Paulo
# 35636       SP    Sao Paulo
# 40456       SP    Sao Paulo
# 5035        SP    Sao Paulo
# 16772       SP    Sao Paulo
# 30958       SP    Sao Paulo
# 9885        SP    Sao Paulo
# 30923       SP    Sao Paulo
# 15148       SP    Sao Paulo
# 21680       SP    Sao Paulo
# 11086       SP    Sao Paulo
# 21636       SP    Sao Paulo
# 30139       SP    Sao Paulo
# 14825       SP    Sao Paulo
# 24198       SP    Sao Paulo
# 12570       SP    Sao Paulo
# 17346       SP    Sao Paulo
# 21647       SP    Sao Paulo
# 9151        SP    Sao Paulo
# ...        ...          ...
# 28033       SP    Sao Paulo
# ...

# %%
[['cidade_busca' , 'universidade_nome','nome','nota_integral_ampla','nota_parcial_ampla']]
# Out:
# [['cidade_busca',
#   'universidade_nome',
#   'nome',
#   'nota_integral_ampla',
#   'nota_parcial_ampla']]

# %%
# Mostrar os 5 maiores mensalidades

df.nlargest(6, 'mensalidade')
# Out:
#       uf_busca         cidade_busca  \
# 31987       MS         Campo Grande
# 12916       CE              Crateus
# 32058       SP            Sao Paulo
# 37058       CE              Crateus
# 31940       AC           Rio Branco
# 32047       SP  Presidente Prudente
#
#                                universidade_nome  \
# 31987          Universidade Anhanguera - UNIDERP
# 12916          Faculdade Princesa do Oeste - FPO
# 32058  Universidade Cidade de São Paulo - UNICID
# 37058          Faculdade Princesa do Oeste - FPO
# 31940        Faculdade Barão do Rio Branco - FAB
# 32047   Universidade do Oeste Paulista - UNOESTE
#
#                                              campus_nome        nome  \
# 31987                 CAMPO GRANDE - SEDE - Miguel Couto    Medicina
# 12916                         UNIDADE SEDE - São Vicente  Enfermagem
# 32058  UNIVERSIDADE CIDADE DE SÃO PAULO - UNICID - SE...    Medicina
# 37058                         UNIDADE SEDE - São Vicente  Psicologia
# ...

# %%
# 5 menores mensalidades

df.nsmallest(6, 'mensalidade')
# Out:
#       uf_busca     cidade_busca  \
# 20454       PA         Santarem
# 22934       DF         Brasilia
# 39118       ES          Vitoria
# 30989       SP      Sao VIcente
# 20836       AC       Acrelandia
# 20838       AC  Cruzeiro do Sul
#
#                                        universidade_nome  \
# 20454                       Universidade Paulista - UNIP
# 22934  Centro Universitário Planalto do Distrito Fede...
# 39118                       Universidade Paulista - UNIP
# 30989                     Faculdade de São VIcente - FSV
# 20836                       Universidade Paulista - UNIP
# 20838                       Universidade Paulista - UNIP
#
#                                              campus_nome  \
# 20454                                  SANTARÉM - Fátima
# 22934  DF03 - UNIDADE BRASIL CENTRAL - Taguatinga Nor...
# 39118                         VITORIA I - Barro Vermelho
# 30989                              UNIDADE SEDE - Centro
# ...
